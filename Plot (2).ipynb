# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('matches')

# %%
d1=data['team1'].value_counts()#1st series
d2=data['team2'].value_counts()#2nd series
d1.add(d2,fill_value=0).sort_values(ascending=False).head().plot(kind='bar')#adding the series

# %%
#Question: 2
def team_record(team1,team2):
    mask1=data['team1']==team1
    mask2=data['team2']==team2
    data1=data[mask1 & mask2]
    mask3=data['team2']==team1
    mask4=data['team1']==team2
    data2=data[mask3 & mask4]
    return data2['winner'].value_counts()+data1['winner'].value_counts()

# %%
team_record('Mumbai Indians','Chennai Super Kings')
# Out:
# Chennai Super Kings    10
# Mumbai Indians         12
# Name: winner, dtype: int64

# %%
data2=data.drop_duplicates(subset='season',keep='last')

# %%
data2
# Out:
#       id  season          city        date                team1  \
# 58    59    2017     Hyderabad  21-05-2017       Mumbai Indians
# 116  117    2008        Mumbai  01-06-2008  Chennai Super Kings
# 173  174    2009  Johannesburg  24-05-2009      Deccan Chargers
# 233  234    2010        Mumbai  25-04-2010  Chennai Super Kings
# 306  307    2011       Chennai  28-05-2011  Chennai Super Kings
# 380  381    2012       Chennai  27-05-2012  Chennai Super Kings
# 456  457    2013       Kolkata  26-05-2013       Mumbai Indians
# 516  517    2014     Bangalore  01-06-2014      Kings XI Punjab
# 575  576    2015       Kolkata  24-05-2015       Mumbai Indians
# 635  636    2016     Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
data2['team1'].value_counts()+data2['team2'].value_counts()
# Out:
# Chennai Super Kings            6.0
# Deccan Chargers                NaN
# Kings XI Punjab                NaN
# Kolkata Knight Riders          NaN
# Mumbai Indians                 4.0
# Rajasthan Royals               NaN
# Rising Pune Supergiant         NaN
# Royal Challengers Bangalore    NaN
# Sunrisers Hyderabad            NaN
# dtype: float64
